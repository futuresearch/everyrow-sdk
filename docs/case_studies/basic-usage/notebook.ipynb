# %% [markdown]
# # everyrow SDK Basic Usage
#
# This notebook demonstrates all the core operations in the everyrow SDK:
#
# 1. **Screen** - Filter rows based on criteria that need judgment
# 2. **Rank** - Score rows by qualitative factors
# 3. **Dedupe** - Deduplicate when fuzzy matching fails
# 4. **Merge** - Join tables when keys don't match exactly
# 5. **Derive** - Add computed columns (no AI needed)
# 6. **Single Agent** - Web research on a single input
# 7. **Agent Map** - Web research on every row of a dataframe
#
# Get an API key at [everyrow.io/api-key](https://everyrow.io/api-key) to run this notebook.

# %%
import os
from textwrap import dedent

from dotenv import load_dotenv
from pandas import DataFrame
from pydantic import BaseModel, Field

from everyrow.session import create_session

load_dotenv()
# Out:
# True

# %% [markdown]
# ## 1. Screen
#
# Filter rows based on criteria you can't put in a WHERE clause. This example performs vendor risk assessment - evaluating security track records and financial stability requires judgment, not pattern matching.

# %%
from everyrow.ops import screen


vendors = DataFrame(
    [
        {"company": "Okta", "category": "Identity Management", "website": "okta.com"},
        {"company": "LastPass", "category": "Password Management", "website": "lastpass.com"},
        {"company": "Snowflake", "category": "Data Warehouse", "website": "snowflake.com"},
        {"company": "Cloudflare", "category": "CDN & Security", "website": "cloudflare.com"},
        {"company": "MongoDB", "category": "Database", "website": "mongodb.com"},
    ]
)

print("Input vendors:")
print(vendors.to_string())
# Out:
# Input vendors:
#       company             category         website
# 0        Okta  Identity Management        okta.com
# 1    LastPass  Password Management    lastpass.com
# 2   Snowflake       Data Warehouse   snowflake.com
# 3  Cloudflare       CDN & Security  cloudflare.com
# 4     MongoDB             Database     mongodb.com

# %%
# Basic screen - returns only passes/fails boolean
basic_screen_result = await screen(
    task=dedent("""
        Perform vendor risk assessment for each company. Research and evaluate:

        1. Security track record: Have they had any significant data breaches or security
        incidents in the past 3 years? How did they respond?

        2. Financial stability: Are there signs of financial distress (major layoffs,
        funding difficulties, declining revenue)?

        3. Overall recommendation: Based on your research, should we proceed with
        this vendor for enterprise use?

        Only approve vendors with low or medium risk and no unresolved critical security incidents.
    """),
    input=vendors,
)

print("Basic Screen Results (passes/fails only):")
print(basic_screen_result.data.to_string())
# Out:
# TaskResultResponse(task_id=UUID('5837e0b8-4109-431b-a095-a21e9bf4b565'), status=<TaskStatus.COMPLETED: 'completed'>, artifact_id=UUID('2892391d-26de-44d3-9f5f-07ccd88074d0'), data=[TaskResultResponseDataType0Item(additional_properties={'company': 'Snowflake', 'category': 'Data Warehouse', 'website': 'snowflake.com', 'research': {'screening_result': "Snowflake was the target of a large-scale credential-stuffing campaign in May 2024 that affected over 160 customers [dd5dc7]. While not a breach of Snowflake's own infrastructure, the company responded by implementing mandatory MFA options and extensive hardening guidance [dd5dc7]. Financials remain strong with 28-29% revenue growth and high retention rates, despite slowing growth compared to previous years. Deductions: The incident was a configuration issue rather than a core platform breach, and the response was proactive, leading to a Medium risk.", 'passes': "Snowflake was the target of a large-scale credential-stuffing campaign in May 2024 that affected over 160 customers [dd5dc7]. While not a breach of Snowflake's own infrastructure, the company responded by implementing mandatory MFA options and extensive hardening guidance [dd5dc7]. Financials remain strong with 28-29% revenue growth and high retention rates, despite slowing growth compared to previous years. Deductions: The incident was a configuration issue rather than a core platform breach, and the response was proactive, leading to a Medium risk."}, 'passes': True}), TaskResultResponseDataType0Item(additional_properties={'company': 'Cloudflare', 'category': 'CDN & Security', 'website': 'cloudflare.com', 'research': {'screening_result': "Cloudflare reported a security incident in November 2023 where an attacker used stolen Okta tokens to access an internal Atlassian server; Cloudflare responded with a 'Code Red' remediation that was completed by early 2024. A separate incident in March 2025 involved compromised third-party vendor accounts (Salesloft/Drift) but did not affect core infrastructure. Financially, Cloudflare is stable, reporting ~30% revenue growth and hitting $2B+ annual revenue targets. Deductions: Transparent incident handling and strong financials result in a Low/Medium risk.", 'passes': "Cloudflare reported a security incident in November 2023 where an attacker used stolen Okta tokens to access an internal Atlassian server; Cloudflare responded with a 'Code Red' remediation that was completed by early 2024. A separate incident in March 2025 involved compromised third-party vendor accounts (Salesloft/Drift) but did not affect core infrastructure. Financially, Cloudflare is stable, reporting ~30% revenue growth and hitting $2B+ annual revenue targets. Deductions: Transparent incident handling and strong financials result in a Low/Medium risk."}, 'passes': True}), TaskResultResponseDataType0Item(additional_properties={'company': 'MongoDB', 'category': 'Database', 'website': 'mongodb.com', 'research': {'screening_result': "MongoDB experienced a phishing-driven support system breach in December 2023 [160140]. A critical unauthenticated memory disclosure vulnerability, 'MongoBleed' (CVE-2025-14847), was disclosed in December 2025, affecting versions back to 2017. MongoDB released patches in late December 2025 and January 2026. Financials show strong growth, with fiscal 2025 revenue reaching $2.01 billion (20% YoY increase) and raised guidance for 2026. Deductions: While 'MongoBleed' was severe, the availability of patches and the company's strong financial performance suggest a manageable Medium risk.", 'passes': "MongoDB experienced a phishing-driven support system breach in December 2023 [160140]. A critical unauthenticated memory disclosure vulnerability, 'MongoBleed' (CVE-2025-14847), was disclosed in December 2025, affecting versions back to 2017. MongoDB released patches in late December 2025 and January 2026. Financials show strong growth, with fiscal 2025 revenue reaching $2.01 billion (20% YoY increas ...
# Basic Screen Results (passes/fails only):
#       company        category         website                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      research  passes
# 0   Snowflake  Data Warehouse   snowflake.com                                                                {'screening_result': 'Snowflake was the target of a large-scale credential-stuffing campaign in May 2024 that affected over 160 customers [dd5dc7]. While not a breach of Snowflake's own infrastructure, the company responded by implementing mandatory MFA options and extensive hardening guidance [dd5dc7]. Financials remain strong with 28-29% revenue growth and high retention rates, despite slowing growth compared to previous years. Deductions: The incident was a configuration issue rather than a core platform breach, and the response was proactive, leading to a Medium risk.', 'passes': 'Snowflake was the target of a large-scale credential-stuffing campaign in May 2024 that affected over 160 customers [dd5dc7]. While not a breach of Snowflake's own infrastructure, the company responded by implementing mandatory MFA options and extensive hardening guidance [dd5dc7]. Financials remain strong with 28-29% revenue growth and high retention rates, despite slowing growth compared to previous years. Deductions: The incident was a configuration issue rather than a core platform breach, and the response was proactive, leading to a Medium risk.'}    True
# 1  Cloudflare  CDN & Security  cloudflare.com                                                  {'screening_result': 'Cloudflare reported a security incident in November 2023 where an attacker used stolen Okta tokens to access an internal Atlassian server; Cloudflare responded with a 'Code Red' remediation that was completed by early 2024. A separate incident in March 2025 involved compromised third-party vendor accounts (Salesloft/Drift) but did not affect core infrastructure. Financially, Cloudflare is stable, reporting ~30% revenue growth and hitting $2B+ annual revenue targets. Deductions: Transparent incident handling and strong financials result in a Low/Medium risk.', 'passes': 'Cloudflare reported a security incident in November 2023 where an attacker used stolen Okta tokens to access an internal Atlassian server; Cloudflare responded with a 'Code Red' remediation that was completed by early 2024. A separate incident in March 2025 involved compromised third-party vendor accounts (Salesloft/Drift) but did not affect core infrastructure. Financially, Cloudflare is stable, reporting ~30% revenue growth and hitting $2B+ annual revenue targets. Deductions: Transparent incident handling and strong financials result in a Low/Medium risk.'}    True
# 2     MongoDB        Database     mongodb.com  {'screening_result': 'MongoDB experienced a phishing-driven support system breach in December 2023 [160140]. A critical unauthenticated memory disclosure vulnerability, 'MongoBleed' (CVE-2025-14847), was disclosed in December 2025, affecting versions back to 2017. MongoDB released patches in late December 2025 and January 2026. Financials show strong growth, with fiscal 2025 revenue reaching $2.01 billion (20% YoY increase) and raised guidance for 2026. Deductions: While 'MongoBleed' was severe, the availability of patches and the company's strong financial performance suggest a manageable Medium risk.', 'passes': 'MongoDB experienced a phishing-driven support system breach in December 2023 [160140]. A critical unauthenticated memory disclosure vulnerability, 'MongoBleed' (CVE-2025-14847), was disclosed in December 2025, affecting versions back to 2017. MongoDB released patches in late December 2025 and January 2026. Financials show strong growth, with fiscal 2025 revenue reaching $2.01 billion (20% YoY increase) and raised guidance for 2026. Deductions: While 'MongoBleed' was severe, the availability of patches and the company's strong financial performance suggest a manageable Medium risk.'}    True

# %%
# Screen with response_model for additional structured context
class VendorRiskAssessment(BaseModel):
    passes: bool = Field(description="Whether the vendor passes risk assessment")
    risk_level: str = Field(description="Risk level: Low, Medium, or High")
    security_summary: str = Field(description="Brief summary of security track record")
    financial_summary: str = Field(description="Brief summary of financial stability")


detailed_screen_result = await screen(
    task=dedent("""
        Perform vendor risk assessment for each company. Research and evaluate:

        1. Security track record: Have they had any significant data breaches or security
        incidents in the past 3 years? How did they respond?

        2. Financial stability: Are there signs of financial distress (major layoffs,
        funding difficulties, declining revenue)?

        3. Overall recommendation: Based on your research, should we proceed with
        this vendor for enterprise use?

        Only approve vendors with low or medium risk and no unresolved critical security incidents.
    """),
    input=vendors,
    response_model=VendorRiskAssessment,
)

print("Detailed Screen Results (with structured context):")
print(detailed_screen_result.data.to_string())
# Out:
# TaskResultResponse(task_id=UUID('713adf55-a975-4345-aab3-59f78bc65adf'), status=<TaskStatus.COMPLETED: 'completed'>, artifact_id=UUID('d0b17291-1e52-4350-a6ce-f004ca9ed9ff'), data=[TaskResultResponseDataType0Item(additional_properties={'company': 'Snowflake', 'category': 'Data Warehouse', 'website': 'snowflake.com', 'research': {'screening_result': "Snowflake was at the center of a massive security event in mid-2024 where over 160 customer environments (including AT&T and Ticketmaster) were breached. While Snowflake's core systems were not compromised, the lack of mandated MFA for customer accounts was a critical factor. Snowflake has since responded by mandating MFA for all users. Financially, Snowflake shows strong revenue growth (~$3.4B in FY2025, up 29%) and high net revenue retention (125-127%), though it continues to report substantial GAAP net losses (~$1B annually). The 2024 incident is considered resolved through policy changes (mandatory MFA), and the financial losses are typical for a high-growth SaaS firm with positive cash flow. Risk is medium. Sources: [https://cloudsecurityalliance.org/blog/2025/05/07/unpacking-the-2024-snowflake-data-breach], [https://docs.snowflake.com/en/user-guide/security-mfa-rollout], [https://www.snowflake.com/en/news/press-releases/snowflake-reports-financial-results-for-the-fourth-quarter-and-full-year-of-fiscal-2025/].", 'passes': "Snowflake was at the center of a massive security event in mid-2024 where over 160 customer environments (including AT&T and Ticketmaster) were breached. While Snowflake's core systems were not compromised, the lack of mandated MFA for customer accounts was a critical factor. Snowflake has since responded by mandating MFA for all users. Financially, Snowflake shows strong revenue growth (~$3.4B in FY2025, up 29%) and high net revenue retention (125-127%), though it continues to report substantial GAAP net losses (~$1B annually). The 2024 incident is considered resolved through policy changes (mandatory MFA), and the financial losses are typical for a high-growth SaaS firm with positive cash flow. Risk is medium. Sources: [https://cloudsecurityalliance.org/blog/2025/05/07/unpacking-the-2024-snowflake-data-breach], [https://docs.snowflake.com/en/user-guide/security-mfa-rollout], [https://www.snowflake.com/en/news/press-releases/snowflake-reports-financial-results-for-the-fourth-quarter-and-full-year-of-fiscal-2025/]."}, 'passes': True}), TaskResultResponseDataType0Item(additional_properties={'company': 'Cloudflare', 'category': 'CDN & Security', 'website': 'cloudflare.com', 'research': {'screening_result': "Cloudflare's security track record is generally strong, though it experienced a breach of its Atlassian server in November 2023, which was a follow-on from the Okta support system compromise. Cloudflare successfully mitigated the incident with no impact on customer data or services. In 2025, the company suffered several significant service outages due to internal bugs and network challenges, which are operational rather than security risks. Financially, Cloudflare is very stable, with revenue reaching approximately $1.67 billion in 2024 and a 2025 target of over $2.1 billion (25%+ growth). Given the robust response to the 2023 incident and transparent handling of outages, it is a low/medium risk vendor. Sources: [https://blog.cloudflare.com/thanksgiving-2023-security-incident/], [https://blog.cloudflare.com/18-november-2025-outage/], [https://www.cloudflare.com/press/press-releases/2025/cloudflare-announces-fourth-quarter-and-fiscal-year-2024-financial-results/].", 'passes': "Cloudflare's security track record is generally strong, though it experienced a breach of its Atlassian server in November 2023, which was a follow-on from the Okta support system compromise. Cloudflare successfully mitigated the incident with no impact on customer data or services. In 2025, the company suffered several significant service outages due to internal bugs and network chall ...
# Detailed Screen Results (with structured context):
#       company        category         website                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            research  passes
# 0   Snowflake  Data Warehouse   snowflake.com                  {'screening_result': 'Snowflake was at the center of a massive security event in mid-2024 where over 160 customer environments (including AT&T and Ticketmaster) were breached. While Snowflake's core systems were not compromised, the lack of mandated MFA for customer accounts was a critical factor. Snowflake has since responded by mandating MFA for all users. Financially, Snowflake shows strong revenue growth (~$3.4B in FY2025, up 29%) and high net revenue retention (125-127%), though it continues to report substantial GAAP net losses (~$1B annually). The 2024 incident is considered resolved through policy changes (mandatory MFA), and the financial losses are typical for a high-growth SaaS firm with positive cash flow. Risk is medium. Sources: [https://cloudsecurityalliance.org/blog/2025/05/07/unpacking-the-2024-snowflake-data-breach], [https://docs.snowflake.com/en/user-guide/security-mfa-rollout], [https://www.snowflake.com/en/news/press-releases/snowflake-reports-financial-results-for-the-fourth-quarter-and-full-year-of-fiscal-2025/].', 'passes': 'Snowflake was at the center of a massive security event in mid-2024 where over 160 customer environments (including AT&T and Ticketmaster) were breached. While Snowflake's core systems were not compromised, the lack of mandated MFA for customer accounts was a critical factor. Snowflake has since responded by mandating MFA for all users. Financially, Snowflake shows strong revenue growth (~$3.4B in FY2025, up 29%) and high net revenue retention (125-127%), though it continues to report substantial GAAP net losses (~$1B annually). The 2024 incident is considered resolved through policy changes (mandatory MFA), and the financial losses are typical for a high-growth SaaS firm with positive cash flow. Risk is medium. Sources: [https://cloudsecurityalliance.org/blog/2025/05/07/unpacking-the-2024-snowflake-data-breach], [https://docs.snowflake.com/en/user-guide/security-mfa-rollout], [https://www.snowflake.com/en/news/press-releases/snowflake-reports-financial-results-for-the-fourth-quarter-and-full-year-of-fiscal-2025/].'}    True
# 1  Cloudflare  CDN & Security  cloudflare.com                                                                                                                            {'screening_result': 'Cloudflare's security track record is generally strong, though it experienced a breach of its Atlassian server in November 2023, which was a follow-on from the Okta support system compromise. Cloudflare successfully mitigated the incident with no impact on customer data or services. In 2025, the company suffered several significant service outages due to internal bugs and network challenges, which are operational rather than security risks. Financially, Cloudflare is very stable, with revenue reaching approximately $1.67 billion in 2024 and a 2025 target of over $2.1 billion (25%+ growth). Given the robust response to the 2023 incident and transparent handling of outages, it is a low/medium risk vendor. Sources: [https://blog.cloudflare.com/thanksgiving-2023-security-incident/], [https://blog.cloudflare.com/18-november-2025-outage/], [https://www.cloudflare.com/press/press-releases/2025/cloudflare-announces-fourth-quarter-and-fiscal-year-2024-financial-results/].', 'passes': 'Cloudflare's security track record is generally strong, though it experienced a breach of its Atlassian server in November 2023, which was a follow-on from the Okta support system compromise. Cloudflare successfully mitigated the incident with no impact on customer data or services. In 2025, the company suffered several significant service outages due to internal bugs and network challenges, which are operational rather than security risks. Financially, Cloudflare is very stable, with revenue reaching approximately $1.67 billion in 2024 and a 2025 target of over $2.1 billion (25%+ growth). Given the robust response to the 2023 incident and transparent handling of outages, it is a low/medium risk vendor. Sources: [https://blog.cloudflare.com/thanksgiving-2023-security-incident/], [https://blog.cloudflare.com/18-november-2025-outage/], [https://www.cloudflare.com/press/press-releases/2025/cloudflare-announces-fourth-quarter-and-fiscal-year-2024-financial-results/].'}    True
# 2     MongoDB        Database     mongodb.com  {'screening_result': 'MongoDB faced two notable incidents in the past 3 years: a December 2023 breach of its corporate systems and a critical vulnerability known as 'MongoBleed' (CVE-2025-14847) disclosed in December 2025. MongoBleed allowed unauthenticated remote memory disclosure. MongoDB responded rapidly to both, concluding its 2023 investigation by early 2024 and releasing patched versions (e.g., 8.0.17) for MongoBleed within weeks of discovery. Financially, MongoDB is stable, reporting over $2 billion in fiscal 2025 revenue with roughly 19% year-over-year growth and positive earnings revisions. Because the critical incidents have been resolved through patching and investigation, the vendor presents a medium risk. Sources: [https://mongodb.com/company/blog/news/mongodb-server-security-update-december-2025], [https://www.mongodb.com/company/blog/news/mongodb-security-incident-post-event-summary-january-23-2024], [https://investors.mongodb.com/news-releases/news-release-details/mongodb-inc-announces-fourth-quarter-and-full-year-fiscal-2025].', 'passes': 'MongoDB faced two notable incidents in the past 3 years: a December 2023 breach of its corporate systems and a critical vulnerability known as 'MongoBleed' (CVE-2025-14847) disclosed in December 2025. MongoBleed allowed unauthenticated remote memory disclosure. MongoDB responded rapidly to both, concluding its 2023 investigation by early 2024 and releasing patched versions (e.g., 8.0.17) for MongoBleed within weeks of discovery. Financially, MongoDB is stable, reporting over $2 billion in fiscal 2025 revenue with roughly 19% year-over-year growth and positive earnings revisions. Because the critical incidents have been resolved through patching and investigation, the vendor presents a medium risk. Sources: [https://mongodb.com/company/blog/news/mongodb-server-security-update-december-2025], [https://www.mongodb.com/company/blog/news/mongodb-security-incident-post-event-summary-january-23-2024], [https://investors.mongodb.com/news-releases/news-release-details/mongodb-inc-announces-fourth-quarter-and-full-year-fiscal-2025].'}    True

# %% [markdown]
# ## 2. Rank
#
# Score rows by things you can't put in a database field. This example ranks AI research organizations by leadership citation counts - information that requires researching each org's leaders and their publications.

# %%
from everyrow.ops import rank

ai_research_orgs = DataFrame(
    [
        {"organization": "OpenAI", "type": "Private lab", "founded": 2015},
        {"organization": "Google DeepMind", "type": "Corporate lab", "founded": 2010},
        {"organization": "Anthropic", "type": "Private lab", "founded": 2021},
        {"organization": "Meta FAIR", "type": "Corporate lab", "founded": 2013},
        {"organization": "Microsoft Research", "type": "Corporate lab", "founded": 1991},
        {"organization": "Stanford HAI", "type": "Academic", "founded": 2019},
    ]
)

print("AI Research Organizations:")
print(ai_research_orgs.to_string())
# Out:
# AI Research Organizations:
#          organization           type  founded
# 0              OpenAI    Private lab     2015
# 1     Google DeepMind  Corporate lab     2010
# 2           Anthropic    Private lab     2021
# 3           Meta FAIR  Corporate lab     2013
# 4  Microsoft Research  Corporate lab     1991
# 5        Stanford HAI       Academic     2019

# %%
rank_task = dedent("""
    Research the total citation count of all leaders of the given AI research organization.

    A leader is defined as a C-Suite or founder of the company.
    Citation count should count all major publications. Top ten by each person is sufficient.
""")

# Basic ranking - returns only the score field
basic_rank_result = await rank(
    task=rank_task,
    input=ai_research_orgs,
    field_name="contribution_score",
    field_type="int",
    ascending_order=False,
)

print("Basic Rankings (score only):")
print(basic_rank_result.data.to_string())
# Out:
# TaskResultResponse(task_id=UUID('323f344b-c42d-4dab-919d-850199ddec9f'), status=<TaskStatus.COMPLETED: 'completed'>, artifact_id=UUID('3283dc61-70ec-4fde-adc2-f3a0f83b9fd4'), data=[TaskResultResponseDataType0Item(additional_properties={'organization': 'OpenAI', 'type': 'Private lab', 'founded': 2015, 'research': {'contribution_score': "OpenAI's leadership and founding team (11 co-founders) were identified from official founding announcements and Wikipedia [2, 16, 22]. Citations were collected from Google Scholar profiles. Key leaders include Ilya Sutskever (747,609 citations) [13], Diederik (Durk) Kingma (341,972 citations) [24], John Schulman (161,754 citations) [15], Wojciech Zaremba (124,058 citations) [14], Mark Chen (140,160 citations) [12], and Andrej Karpathy (77,898 citations) [16]. Other founders like Sam Altman, Greg Brockman, and Elon Musk have low or non-academic citation profiles in AI research (Altman/Brockman ~0-5k; Musk ~4.5k) [4, 5, 22]. Top 10 publications were identified for the most cited researchers [10, 13, 14, 15]. Jakub Pachocki (Chief Scientist) has approximately 30,198 citations according to Semantic Scholar [1, 12]."}, 'contribution_score': 1291410}), TaskResultResponseDataType0Item(additional_properties={'organization': 'Meta FAIR', 'type': 'Corporate lab', 'founded': 2013, 'research': {'contribution_score': "Leadership and citation data for Meta FAIR were identified using Google Scholar and academic profiles. Founders identified include Yann LeCun (Founding Director), Mark Zuckerberg (CEO), and Rob Fergus [7, 18, 20]. Current leadership includes Joelle Pineau (VP, AI Research) [9, 11]. Citation counts were sourced primarily from Google Scholar profiles for each leader as of early 2026. Yann LeCun's citation count is 449,551 [10]. Joelle Pineau's count is 40,842 [9]. Rob Fergus has 5,929 citations [20]. Serkan Piantino, a founding member, has 1,125 [21]. Top 10 publications for key leaders were gathered from Scholar profiles [10, 19]. Mark Zuckerberg and Andrew Bosworth have minimal public research citation profiles despite their executive roles [17, 18]."}, 'contribution_score': 496322}), TaskResultResponseDataType0Item(additional_properties={'organization': 'Google DeepMind', 'type': 'Corporate lab', 'founded': 2010, 'research': {'contribution_score': "Citation counts were retrieved from Google Scholar and other academic indices as of January 2026. The counts for Shane Legg and Mustafa Suleyman were derived from high-authority profiles and recent academic summaries. Koray Kavukcuoglu's count is corroborated by research profile sites. Zoubin Ghahramani and Pushmeet Kohli counts are from their verified Google Scholar profiles. The definitional scope of 'leader' includes C-suite and founders as specified. Citation data for Lila Ibrahim was found to be minimal, reflecting her operational rather than research-focused role."}, 'contribution_score': 5}), TaskResultResponseDataType0Item(additional_properties={'organization': 'Anthropic', 'type': 'Private lab', 'founded': 2021, 'research': {'contribution_score': "Citation counts for Anthropic's leadership were sourced from verified Google Scholar profiles as of early 2026. Dario Amodei, Jared Kaplan, and Sam McCandlish are heavily cited due to their foundational work in LLM scaling laws. Tom Brown and Benjamin Mann are key authors on the GPT-3 paper, which accounts for a large portion of their citations. Jack Clark's citations are primarily in the realm of AI policy and measurement. Daniela Amodei and Mike Krieger have lower scholarly citation counts as their roles are predominantly executive/operational. Total organization citation count is an aggregate of these primary research leaders."}, 'contribution_score': 5}), TaskResultResponseDataType0Item(additional_properties={'organization': 'Microsoft Research', 'type': 'Corporate lab', 'founded': 1991, 'research': {'contribution_score': 'Microsoft Research was founded in 1991 by Richard Rashid, Bill Gates, a ...
# Basic Rankings (score only):
#          organization           type  founded                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          research  contribution_score
# 0              OpenAI    Private lab     2015  {'contribution_score': 'OpenAI's leadership and founding team (11 co-founders) were identified from official founding announcements and Wikipedia [2, 16, 22]. Citations were collected from Google Scholar profiles. Key leaders include Ilya Sutskever (747,609 citations) [13], Diederik (Durk) Kingma (341,972 citations) [24], John Schulman (161,754 citations) [15], Wojciech Zaremba (124,058 citations) [14], Mark Chen (140,160 citations) [12], and Andrej Karpathy (77,898 citations) [16]. Other founders like Sam Altman, Greg Brockman, and Elon Musk have low or non-academic citation profiles in AI research (Altman/Brockman ~0-5k; Musk ~4.5k) [4, 5, 22]. Top 10 publications were identified for the most cited researchers [10, 13, 14, 15]. Jakub Pachocki (Chief Scientist) has approximately 30,198 citations according to Semantic Scholar [1, 12].'}             1291410
# 1           Meta FAIR  Corporate lab     2013                                                                {'contribution_score': 'Leadership and citation data for Meta FAIR were identified using Google Scholar and academic profiles. Founders identified include Yann LeCun (Founding Director), Mark Zuckerberg (CEO), and Rob Fergus [7, 18, 20]. Current leadership includes Joelle Pineau (VP, AI Research) [9, 11]. Citation counts were sourced primarily from Google Scholar profiles for each leader as of early 2026. Yann LeCun's citation count is 449,551 [10]. Joelle Pineau's count is 40,842 [9]. Rob Fergus has 5,929 citations [20]. Serkan Piantino, a founding member, has 1,125 [21]. Top 10 publications for key leaders were gathered from Scholar profiles [10, 19]. Mark Zuckerberg and Andrew Bosworth have minimal public research citation profiles despite their executive roles [17, 18].'}              496322
# 2     Google DeepMind  Corporate lab     2010                                                                                                                                                                                                                                                        {'contribution_score': 'Citation counts were retrieved from Google Scholar and other academic indices as of January 2026. The counts for Shane Legg and Mustafa Suleyman were derived from high-authority profiles and recent academic summaries. Koray Kavukcuoglu's count is corroborated by research profile sites. Zoubin Ghahramani and Pushmeet Kohli counts are from their verified Google Scholar profiles. The definitional scope of 'leader' includes C-suite and founders as specified. Citation data for Lila Ibrahim was found to be minimal, reflecting her operational rather than research-focused role.'}                   5
# 3           Anthropic    Private lab     2021                                                                                                                                                                                           {'contribution_score': 'Citation counts for Anthropic's leadership were sourced from verified Google Scholar profiles as of early 2026. Dario Amodei, Jared Kaplan, and Sam McCandlish are heavily cited due to their foundational work in LLM scaling laws. Tom Brown and Benjamin Mann are key authors on the GPT-3 paper, which accounts for a large portion of their citations. Jack Clark's citations are primarily in the realm of AI policy and measurement. Daniela Amodei and Mike Krieger have lower scholarly citation counts as their roles are predominantly executive/operational. Total organization citation count is an aggregate of these primary research leaders.'}                   5
# 4  Microsoft Research  Corporate lab     1991                                                                                                                                                                    {'contribution_score': 'Microsoft Research was founded in 1991 by Richard Rashid, Bill Gates, and Nathan Myhrvold. Peter Lee is the current President of MSR, and Eric Horvitz is the Chief Scientific Officer of Microsoft and a key leader in its research efforts. Citation counts were sourced from Google Scholar and academic ranking sites (Research.com, ResearchGate). Bill Gates does not have a standard academic citation profile, but his key computer science publication (Pancake Sorting) and significant patents are noted. Nathan Myhrvold has a diverse research portfolio in physics and paleontology. Richard Rashid, Peter Lee, and Eric Horvitz are highly cited computer scientists.'}                   5
# 5        Stanford HAI       Academic     2019                                                                                                                                                                                                                                                                                                                                          {'contribution_score': 'Stanford HAI was founded in 2019 by Fei-Fei Li and John Etchemendy. Christopher Manning and James Landay serve as Associate Directors/Co-Directors. All are prominent Stanford faculty with significant citation impact. Fei-Fei Li is known for ImageNet; Christopher Manning is a world leader in NLP; James Landay is a pioneer in HCI; John Etchemendy is a noted philosopher of logic. Citation totals and top publications were extracted from their public Google Scholar profiles and university bios.'}                   5

# %%
# Ranking with response_model for additional structured context
class ContributionRanking(BaseModel):
    contribution_score: int = Field(description="Total citation count")
    most_significant_contribution: str = Field(
        description="Single most important paper authored by a firm leader"
    )


detailed_rank_result = await rank(
    task=rank_task + "\n\nAlso identify their single most significant contribution.",
    input=ai_research_orgs,
    field_name="contribution_score",
    response_model=ContributionRanking,
    ascending_order=False,
)

print("Detailed Rankings (with structured context):")
print(detailed_rank_result.data.to_string())
# Out:
# TaskResultResponse(task_id=UUID('bdb71be7-42e1-4064-9d4a-51e63dc02e93'), status=<TaskStatus.COMPLETED: 'completed'>, artifact_id=UUID('c2057ef4-fca7-41ba-a846-f25a4783274f'), data=[TaskResultResponseDataType0Item(additional_properties={'organization': 'OpenAI', 'type': 'Private lab', 'founded': 2015, 'contribution_score': 1610443, 'research': {'most_significant_contribution': 'The collective contribution of the founding team was the creation of the GPT architecture and the transition of AI research from academic models to massive-scale production systems. Individually, Sutskever is cited for Sequence to Sequence learning, Kingma for Adam and VAEs, and Altman for the strategic scaling of the organization.', 'contribution_score': 'Calculated by summing the total Google Scholar citation counts of key current and former C-Suite/founders: Ilya Sutskever (747,609), Diederik P. Kingma (341,972), John Schulman (161,754), Mark Chen (140,160), Wojciech Zaremba (124,058), Andrej Karpathy (77,898), Sam Altman (8,464), Greg Brockman (747), Elon Musk (4,509), and others like Trevor Blackwell and Vicki Cheung (approx. 3,272 combined). Citations sourced from Google Scholar and Semantics Scholar profiles as of early 2026.'}, 'most_significant_contribution': 'Founding of OpenAI and the deployment of the Generative Pre-trained Transformer (GPT) series, including ChatGPT, and reorienting the field around large-scale reinforcement learning and reasoning models.'}), TaskResultResponseDataType0Item(additional_properties={'organization': 'Stanford HAI', 'type': 'Academic', 'founded': 2019, 'research': {'most_significant_contribution': "Fei-Fei Li's ImageNet is the most cited and foundational work. Christopher Manning's 'Foundations of Statistical Natural Language Processing' and the development of GloVe and Stanford CoreNLP are the primary contributions to NLP. James Landay is recognized for pioneering Human-Computer Interaction (HCI) research.", 'contribution_score': 'Calculated from Google Scholar totals for directors and founders: Fei-Fei Li (336,221), Christopher Manning (310,106), Carlos Guestrin (164,822), James Landay (34,817), and John Etchemendy (approx. 1,359). Russell Wald is primarily policy-focused with low academic citation counts (approx. 0-50).'}, 'most_significant_contribution': 'Establishment of ImageNet (Fei-Fei Li), which catalyzed the deep learning revolution, and the development of foundational NLP textbooks and Universal Dependencies (Christopher Manning).', 'contribution_score': 847325}), TaskResultResponseDataType0Item(additional_properties={'organization': 'Anthropic', 'type': 'Private lab', 'founded': 2021, 'most_significant_contribution': 'Development of Scaling Laws for Neural Language Models and Constitutional AI for model alignment.', 'research': {'contribution_score': "Total citation counts are aggregated from Google Scholar profiles for the seven co-founders of Anthropic as of early 2026. Dario Amodei: 150,047 [https://scholar.google.com/citations?user=6-e-ZBEAAAAJ]; Daniela Amodei: 43,000 [https://www.coindesk.com/web3/2025/06/05/top-50-women-in-web3-and-ai]; Jared Kaplan: 127,843 [https://scholar.google.com/citations?user=KNr3vb4AAAAJ]; Jack Clark: 63,145 [https://0-scholar-google-com.brum.beds.ac.uk/citations?user=wjkaNgcAAAAJ]; Sam McCandlish: 109,064 [https://scholar.google.com/citations?user=gHp0pu4AAAAJ]; Tom Brown: 115,596 [https://scholar.google.com/citations?user=RLvsC94AAAAJ]; and Chris Olah: 105,511 [https://scholar.google.com/citations?user=6dskOSUAAAAJ]. Ben Mann is also noted as a founder with 90,043 citations, but the core 'billionaire' founder list typically focuses on the first seven. Totalling the primary seven founders: 150,047 + 43,000 + 127,843 + 63,145 + 109,064 + 115,596 + 105,511 = 714,206. If Ben Mann (90,043) and Amanda Askell (169,928, Head of Personality Alignment/early leader) are included as C-Suite/Founders, the total rises significantly to over 974,000. Using the confirmed seven-founde ...
# Detailed Rankings (with structured context):
#          organization           type  founded  contribution_score                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              research                                                                                                                                                                               most_significant_contribution
# 0              OpenAI    Private lab     2015             1610443                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     {'most_significant_contribution': 'The collective contribution of the founding team was the creation of the GPT architecture and the transition of AI research from academic models to massive-scale production systems. Individually, Sutskever is cited for Sequence to Sequence learning, Kingma for Adam and VAEs, and Altman for the strategic scaling of the organization.', 'contribution_score': 'Calculated by summing the total Google Scholar citation counts of key current and former C-Suite/founders: Ilya Sutskever (747,609), Diederik P. Kingma (341,972), John Schulman (161,754), Mark Chen (140,160), Wojciech Zaremba (124,058), Andrej Karpathy (77,898), Sam Altman (8,464), Greg Brockman (747), Elon Musk (4,509), and others like Trevor Blackwell and Vicki Cheung (approx. 3,272 combined). Citations sourced from Google Scholar and Semantics Scholar profiles as of early 2026.'}  Founding of OpenAI and the deployment of the Generative Pre-trained Transformer (GPT) series, including ChatGPT, and reorienting the field around large-scale reinforcement learning and reasoning models.
# 1        Stanford HAI       Academic     2019              847325                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     {'most_significant_contribution': 'Fei-Fei Li's ImageNet is the most cited and foundational work. Christopher Manning's 'Foundations of Statistical Natural Language Processing' and the development of GloVe and Stanford CoreNLP are the primary contributions to NLP. James Landay is recognized for pioneering Human-Computer Interaction (HCI) research.', 'contribution_score': 'Calculated from Google Scholar totals for directors and founders: Fei-Fei Li (336,221), Christopher Manning (310,106), Carlos Guestrin (164,822), James Landay (34,817), and John Etchemendy (approx. 1,359). Russell Wald is primarily policy-focused with low academic citation counts (approx. 0-50).'}                   Establishment of ImageNet (Fei-Fei Li), which catalyzed the deep learning revolution, and the development of foundational NLP textbooks and Universal Dependencies (Christopher Manning).
# 2           Anthropic    Private lab     2021              801749  {'contribution_score': 'Total citation counts are aggregated from Google Scholar profiles for the seven co-founders of Anthropic as of early 2026. Dario Amodei: 150,047 [https://scholar.google.com/citations?user=6-e-ZBEAAAAJ]; Daniela Amodei: 43,000 [https://www.coindesk.com/web3/2025/06/05/top-50-women-in-web3-and-ai]; Jared Kaplan: 127,843 [https://scholar.google.com/citations?user=KNr3vb4AAAAJ]; Jack Clark: 63,145 [https://0-scholar-google-com.brum.beds.ac.uk/citations?user=wjkaNgcAAAAJ]; Sam McCandlish: 109,064 [https://scholar.google.com/citations?user=gHp0pu4AAAAJ]; Tom Brown: 115,596 [https://scholar.google.com/citations?user=RLvsC94AAAAJ]; and Chris Olah: 105,511 [https://scholar.google.com/citations?user=6dskOSUAAAAJ]. Ben Mann is also noted as a founder with 90,043 citations, but the core 'billionaire' founder list typically focuses on the first seven. Totalling the primary seven founders: 150,047 + 43,000 + 127,843 + 63,145 + 109,064 + 115,596 + 105,511 = 714,206. If Ben Mann (90,043) and Amanda Askell (169,928, Head of Personality Alignment/early leader) are included as C-Suite/Founders, the total rises significantly to over 974,000. Using the confirmed seven-founder list: ~714,206. Using all identified early leadership: ~974,177. I have reported the sum of the primary seven founders and the head of alignment. (801,749)', 'most_significant_contribution': 'The collective leadership team's most significant research contribution is the empirical discovery of Scaling Laws for Neural Language Models, which proved that model performance scales predictably with compute, data, and parameters [https://sites.krieger.jhu.edu/jared-kaplan/publications/]. Additionally, the team pioneered Constitutional AI, a method for aligning AI systems with human values without human feedback on every prompt [https://www.anthropic.com/news/constitutional-ai-harmlessness-from-ai-feedback].'}                                                                                                           Development of Scaling Laws for Neural Language Models and Constitutional AI for model alignment.
# 3           Meta FAIR  Corporate lab     2013              650767                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 {'most_significant_contribution': 'The most significant contribution from FAIR leadership is Yann LeCun's pioneering work on Convolutional Neural Networks (CNNs), specifically the LeNet architecture, which laid the foundation for modern computer vision [https://en.wikipedia.org/wiki/Yann_LeCun]. Additionally, under Joelle Pineau and Rob Fergus, FAIR has made significant strides in Reinforcement Learning for complex domains like healthcare and the release of open-source models like Llama [https://ai.meta.com/blog/fair-10-year-anniversary-open-science-meta/].', 'contribution_score': 'Total citation counts for the key leaders (founding director, former head, and current head) of Meta FAIR as of 2026. Yann LeCun (Founding Director & Chief AI Scientist): 449,551 [https://scholar.google.com/citations?user=WLN3QrAAAAAJ]; Rob Fergus (Co-founder & current Head of FAIR): 160,374 [https://scholar.google.com/citations?user=GgQ9GEkAAAAJ]; and Joelle Pineau (Former VP of AI Research & Head of FAIR): 40,842 [https://scholar.google.com/citations?user=CEt6_mMAAAAJ]. Summing these three primary leaders: 449,551 + 160,374 + 40,842 = 650,767. This count represents the core leadership responsible for the lab's direction.'}                                                                Invention and popularization of Convolutional Neural Networks (CNNs) and advancements in Reinforcement Learning for robotics and healthcare.
# 4     Google DeepMind  Corporate lab     2010              580000                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           {'contribution_score': 'Combined total citations for Google DeepMind leaders: Demis Hassabis (approx. 255,000) [3], Koray Kavukcuoglu (approx. 305,000) [15], and Shane Legg (approx. 20,000+). Total exceeds 580,000. Data from Google Scholar profiles and industry reports [3, 14, 15, 23].', 'most_significant_contribution': 'Hassabis and Kavukcuoglu are credited with AlphaFold and AlphaGo [3, 5, 20]. Shane Legg is recognized for the formal definition of 'Universal Intelligence' [4, 23]. Hassabis won the 2024 Nobel Prize in Chemistry for AlphaFold [8].'}                                                                                                         Development of AlphaFold for protein structure prediction and AlphaGo for mastering the game of Go.
# 5  Microsoft Research  Corporate lab     1991               25000                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     {'most_significant_contribution': 'Rick Rashid is renowned for the Mach kernel, which forms the basis for modern operating systems like macOS and iOS [11, 28]. Peter Lee is recognized for his work on Proof-Carrying Code and leadership in AI for medicine [21, 24, 27].', 'contribution_score': 'Estimated total citations for Microsoft Research leaders: Richard Rashid (approx. 10,000-15,000 based on ACM/Google Scholar snapshots) [11, 22] and Peter Lee (approx. 10,000-12,000) [6, 21]. Total approx. 25,000. Note: Mustafa Suleyman (CEO of Microsoft AI) has ~24,500 citations [5], but MSR specific leadership focuses on Rashid and Lee [2, 7].'}                                                                                                            Creation and scaling of the Mach operating system kernel and the founding of Microsoft Research.

# %% [markdown]
# ## 3. Dedupe
#
# Deduplicate when fuzzy matching falls short. This example deduplicates academic papers where the same paper may appear with different identifiers (arXiv ID vs DOI), different title formats, or as preprint vs published versions.

# %%
from everyrow.ops import dedupe

papers = DataFrame(
    [
        {
            "title": "Attention Is All You Need",
            "authors": "Vaswani et al.",
            "venue": "NeurIPS 2017",
            "identifier": "10.5555/3295222.3295349",
        },
        {
            "title": "Attention Is All You Need",
            "authors": "Vaswani, Shazeer, Parmar et al.",
            "venue": "arXiv",
            "identifier": "1706.03762",
        },
        {
            "title": "BERT: Pre-training of Deep Bidirectional Transformers for Language Understanding",
            "authors": "Devlin et al.",
            "venue": "NAACL 2019",
            "identifier": "10.18653/v1/N19-1423",
        },
        {
            "title": "BERT: Pre-training of Deep Bidirectional Transformers",
            "authors": "Devlin, Chang, Lee, Toutanova",
            "venue": "arXiv",
            "identifier": "1810.04805",
        },
        {
            "title": "Language Models are Few-Shot Learners",
            "authors": "Brown et al.",
            "venue": "NeurIPS 2020",
            "identifier": "GPT-3",
        },
        {
            "title": "GPT-3: Language Models are Few-Shot Learners",
            "authors": "Brown, Mann, Ryder et al.",
            "venue": "arXiv",
            "identifier": "2005.14165",
        },
        {
            "title": "LLaMA: Open and Efficient Foundation Language Models",
            "authors": "Touvron et al.",
            "venue": "arXiv",
            "identifier": "2302.13971",
        },
        {
            "title": "Llama 2: Open Foundation and Fine-Tuned Chat Models",
            "authors": "Touvron et al.",
            "venue": "arXiv",
            "identifier": "2307.09288",
        },
    ]
)

print(f"Input papers ({len(papers)} rows):")
print(papers.to_string())
# Out:
# Input papers (8 rows):
#                                                                               title                          authors         venue               identifier
# 0                                                         Attention Is All You Need                   Vaswani et al.  NeurIPS 2017  10.5555/3295222.3295349
# 1                                                         Attention Is All You Need  Vaswani, Shazeer, Parmar et al.         arXiv               1706.03762
# 2  BERT: Pre-training of Deep Bidirectional Transformers for Language Understanding                    Devlin et al.    NAACL 2019     10.18653/v1/N19-1423
# 3                             BERT: Pre-training of Deep Bidirectional Transformers    Devlin, Chang, Lee, Toutanova         arXiv               1810.04805
# 4                                             Language Models are Few-Shot Learners                     Brown et al.  NeurIPS 2020                    GPT-3
# 5                                      GPT-3: Language Models are Few-Shot Learners        Brown, Mann, Ryder et al.         arXiv               2005.14165
# 6                              LLaMA: Open and Efficient Foundation Language Models                   Touvron et al.         arXiv               2302.13971
# 7                               Llama 2: Open Foundation and Fine-Tuned Chat Models                   Touvron et al.         arXiv               2307.09288

# %%
dedupe_result = await dedupe(
    input=papers,
    equivalence_relation=dedent("""
        Two entries are duplicates if they represent the same research work, which requires
        verifying through research:

        - An arXiv preprint and its published conference/journal version are duplicates
        - Papers with slightly different titles but same core contribution are duplicates
        - Different author list formats (et al. vs full list) don't matter
        - Papers with different identifiers (arXiv ID vs DOI) may still be duplicates

        However, genuinely different papers (e.g., LLaMA 1 vs LLaMA 2) are NOT duplicates,
        even if authors and topics overlap. Research each paper to determine if they
        report the same findings or are distinct works.
    """),
)

print("Deduplicated Paper List:")
print(dedupe_result.data.to_string())
print(f"\nOriginal entries: {len(papers)}")
print(f"Unique papers: {len(dedupe_result.data)}")
print(f"Duplicates removed: {len(papers) - len(dedupe_result.data)}")
# Out:
# TaskResultResponse(task_id=UUID('8e4d15d0-b264-4677-b17d-80f08e02680b'), status=<TaskStatus.COMPLETED: 'completed'>, artifact_id=UUID('7ec69b9f-9b71-4953-90d7-af4d0ed079ab'), data=[TaskResultResponseDataType0Item(additional_properties={'title': 'Attention Is All You Need', 'authors': 'Vaswani et al.', 'venue': 'NeurIPS 2017', 'identifier': '10.5555/3295222.3295349', 'equivalence_class_id': '19fa4363-4c9a-43e9-a3f5-f7dfaf3c8c9c', 'selected': True, 'equivalence_class_name': 'Attention Is All You Need'}), TaskResultResponseDataType0Item(additional_properties={'title': 'Attention Is All You Need', 'authors': 'Vaswani, Shazeer, Parmar et al.', 'venue': 'arXiv', 'identifier': '1706.03762', 'equivalence_class_id': '19fa4363-4c9a-43e9-a3f5-f7dfaf3c8c9c', 'selected': False, 'equivalence_class_name': 'Attention Is All You Need'}), TaskResultResponseDataType0Item(additional_properties={'title': 'BERT: Pre-training of Deep Bidirectional Transformers for Language Understanding', 'authors': 'Devlin et al.', 'venue': 'NAACL 2019', 'identifier': '10.18653/v1/N19-1423', 'equivalence_class_id': 'df25573c-f5df-41d5-8687-e9cfdccae2a0', 'selected': True, 'equivalence_class_name': 'BERT: Pre-training of Deep Bidirectional Transformers'}), TaskResultResponseDataType0Item(additional_properties={'title': 'BERT: Pre-training of Deep Bidirectional Transformers', 'authors': 'Devlin, Chang, Lee, Toutanova', 'venue': 'arXiv', 'identifier': '1810.04805', 'equivalence_class_id': 'df25573c-f5df-41d5-8687-e9cfdccae2a0', 'selected': False, 'equivalence_class_name': 'BERT: Pre-training of Deep Bidirectional Transformers'}), TaskResultResponseDataType0Item(additional_properties={'title': 'Language Models are Few-Shot Learners', 'authors': 'Brown et al.', 'venue': 'NeurIPS 2020', 'identifier': 'GPT-3', 'equivalence_class_id': '51d2e7ea-cda0-4594-b9df-30995c0840c4', 'selected': False, 'equivalence_class_name': 'GPT-3: Language Models are Few-Shot Learners'}), TaskResultResponseDataType0Item(additional_properties={'title': 'GPT-3: Language Models are Few-Shot Learners', 'authors': 'Brown, Mann, Ryder et al.', 'venue': 'arXiv', 'identifier': '2005.14165', 'equivalence_class_id': '51d2e7ea-cda0-4594-b9df-30995c0840c4', 'selected': True, 'equivalence_class_name': 'GPT-3: Language Models are Few-Shot Learners'}), TaskResultResponseDataType0Item(additional_properties={'title': 'LLaMA: Open and Efficient Foundation Language Models', 'authors': 'Touvron et al.', 'venue': 'arXiv', 'identifier': '2302.13971', 'equivalence_class_id': '2e3665db-e74b-41be-867b-8b775ed2dbd3', 'selected': True}), TaskResultResponseDataType0Item(additional_properties={'title': 'Llama 2: Open Foundation and Fine-Tuned Chat Models', 'authors': 'Touvron et al.', 'venue': 'arXiv', 'identifier': '2307.09288', 'equivalence_class_id': '2f660d1f-9d2d-40b6-911f-ba7b4e00dfe9', 'selected': True})], error=None, additional_properties={})
# Deduplicated Paper List:
#                                                                               title                          authors         venue               identifier                  equivalence_class_id  selected                                 equivalence_class_name
# 0                                                         Attention Is All You Need                   Vaswani et al.  NeurIPS 2017  10.5555/3295222.3295349  19fa4363-4c9a-43e9-a3f5-f7dfaf3c8c9c      True                              Attention Is All You Need
# 1                                                         Attention Is All You Need  Vaswani, Shazeer, Parmar et al.         arXiv               1706.03762  19fa4363-4c9a-43e9-a3f5-f7dfaf3c8c9c     False                              Attention Is All You Need
# 2  BERT: Pre-training of Deep Bidirectional Transformers for Language Understanding                    Devlin et al.    NAACL 2019     10.18653/v1/N19-1423  df25573c-f5df-41d5-8687-e9cfdccae2a0      True  BERT: Pre-training of Deep Bidirectional Transformers
# 3                             BERT: Pre-training of Deep Bidirectional Transformers    Devlin, Chang, Lee, Toutanova         arXiv               1810.04805  df25573c-f5df-41d5-8687-e9cfdccae2a0     False  BERT: Pre-training of Deep Bidirectional Transformers
# 4                                             Language Models are Few-Shot Learners                     Brown et al.  NeurIPS 2020                    GPT-3  51d2e7ea-cda0-4594-b9df-30995c0840c4     False           GPT-3: Language Models are Few-Shot Learners
# 5                                      GPT-3: Language Models are Few-Shot Learners        Brown, Mann, Ryder et al.         arXiv               2005.14165  51d2e7ea-cda0-4594-b9df-30995c0840c4      True           GPT-3: Language Models are Few-Shot Learners
# 6                              LLaMA: Open and Efficient Foundation Language Models                   Touvron et al.         arXiv               2302.13971  2e3665db-e74b-41be-867b-8b775ed2dbd3      True                                                    NaN
# 7                               Llama 2: Open Foundation and Fine-Tuned Chat Models                   Touvron et al.         arXiv               2307.09288  2f660d1f-9d2d-40b6-911f-ba7b4e00dfe9      True                                                    NaN
#
# Original entries: 8
# Unique papers: 8
# Duplicates removed: 0

# %% [markdown]
# ## 4. Merge
#
# Join two tables when the keys don't match exactly. This example merges clinical trial data with pharmaceutical company information - the challenge is that trial sponsors are often subsidiaries or use abbreviated names (e.g., "MSD" instead of "Merck").

# %%
from everyrow.ops import merge

clinical_trials = DataFrame(
    [
        {
            "trial_id": "NCT05432109",
            "sponsor": "Genentech",
            "indication": "Non-small cell lung cancer",
            "phase": "Phase 3",
        },
        {
            "trial_id": "NCT05891234",
            "sponsor": "Janssen Pharmaceuticals",
            "indication": "Multiple myeloma",
            "phase": "Phase 2",
        },
        {
            "trial_id": "NCT05567890",
            "sponsor": "MSD",
            "indication": "Melanoma",
            "phase": "Phase 3",
        },
        {
            "trial_id": "NCT05234567",
            "sponsor": "AbbVie Inc",
            "indication": "Rheumatoid arthritis",
            "phase": "Phase 3",
        },
        {
            "trial_id": "NCT05678901",
            "sponsor": "BMS",
            "indication": "Acute myeloid leukemia",
            "phase": "Phase 2",
        },
    ]
)

pharma_companies = DataFrame(
    [
        {
            "company": "Roche Holding AG",
            "hq_country": "Switzerland",
            "2024_revenue_billions": 58.7,
        },
        {
            "company": "Johnson & Johnson",
            "hq_country": "United States",
            "2024_revenue_billions": 85.2,
        },
        {
            "company": "Merck & Co.",
            "hq_country": "United States",
            "2024_revenue_billions": 60.1,
        },
        {
            "company": "AbbVie",
            "hq_country": "United States",
            "2024_revenue_billions": 56.3,
        },
        {
            "company": "Bristol-Myers Squibb",
            "hq_country": "United States",
            "2024_revenue_billions": 45.0,
        },
    ]
)

print("Clinical Trials:")
print(clinical_trials.to_string())
print("\nPharma Companies:")
print(pharma_companies.to_string())
# Out:
# Clinical Trials:
#       trial_id                  sponsor                  indication    phase
# 0  NCT05432109                Genentech  Non-small cell lung cancer  Phase 3
# 1  NCT05891234  Janssen Pharmaceuticals            Multiple myeloma  Phase 2
# 2  NCT05567890                      MSD                    Melanoma  Phase 3
# 3  NCT05234567               AbbVie Inc        Rheumatoid arthritis  Phase 3
# 4  NCT05678901                      BMS      Acute myeloid leukemia  Phase 2
#
# Pharma Companies:
#                 company     hq_country  2024_revenue_billions
# 0      Roche Holding AG    Switzerland                   58.7
# 1     Johnson & Johnson  United States                   85.2
# 2           Merck & Co.  United States                   60.1
# 3                AbbVie  United States                   56.3
# 4  Bristol-Myers Squibb  United States                   45.0

# %%
merge_result = await merge(
    task=dedent("""
        Merge clinical trial data with parent pharmaceutical company information.

        The sponsor names in the trials table are often subsidiaries or abbreviations:
        - Research which parent company owns each trial sponsor
        - Match trials to their parent company's financial data

        For example, Genentech is a subsidiary of Roche, Janssen is part of J&J,
        MSD is Merck's name outside the US, BMS is Bristol-Myers Squibb.
    """),
    left_table=clinical_trials,
    right_table=pharma_companies,
    merge_on_left="sponsor",
    merge_on_right="company",
)

print("Clinical Trials with Parent Company Data:")
print(merge_result.data.to_string())
# Out:
# TaskResultResponse(task_id=UUID('28c2d5b9-a026-4530-bf2d-62f164032be3'), status=<TaskStatus.COMPLETED: 'completed'>, artifact_id=UUID('d34ab97c-989c-4712-8e5c-dcb335431df5'), data=[TaskResultResponseDataType0Item(additional_properties={'trial_id': 'NCT05432109', 'sponsor': 'Genentech', 'indication': 'Non-small cell lung cancer', 'phase': 'Phase 3', 'company': 'Roche Holding AG', 'hq_country': 'Switzerland', '2024_revenue_billions': 58.7, 'research': {'company': 'This row was matched due to the information in both tables', 'hq_country': 'This row was matched due to the information in both tables', '2024_revenue_billions': 'This row was matched due to the information in both tables'}}), TaskResultResponseDataType0Item(additional_properties={'trial_id': 'NCT05891234', 'sponsor': 'Janssen Pharmaceuticals', 'indication': 'Multiple myeloma', 'phase': 'Phase 2', 'company': 'Johnson & Johnson', 'hq_country': 'United States', '2024_revenue_billions': 85.2, 'research': {'company': 'This row was matched due to the information in both tables', 'hq_country': 'This row was matched due to the information in both tables', '2024_revenue_billions': 'This row was matched due to the information in both tables'}}), TaskResultResponseDataType0Item(additional_properties={'trial_id': 'NCT05567890', 'sponsor': 'MSD', 'indication': 'Melanoma', 'phase': 'Phase 3', 'company': 'Merck & Co.', 'hq_country': 'United States', '2024_revenue_billions': 60.1, 'research': {'company': 'This row was matched due to the information in both tables', 'hq_country': 'This row was matched due to the information in both tables', '2024_revenue_billions': 'This row was matched due to the information in both tables'}}), TaskResultResponseDataType0Item(additional_properties={'trial_id': 'NCT05234567', 'sponsor': 'AbbVie Inc', 'indication': 'Rheumatoid arthritis', 'phase': 'Phase 3', 'company': 'AbbVie', 'hq_country': 'United States', '2024_revenue_billions': 56.3, 'research': {'company': 'This row was matched due to the information in both tables', 'hq_country': 'This row was matched due to the information in both tables', '2024_revenue_billions': 'This row was matched due to the information in both tables'}}), TaskResultResponseDataType0Item(additional_properties={'trial_id': 'NCT05678901', 'sponsor': 'BMS', 'indication': 'Acute myeloid leukemia', 'phase': 'Phase 2', 'company': 'Bristol-Myers Squibb', 'hq_country': 'United States', '2024_revenue_billions': 45.0, 'research': {'company': 'This row was matched due to the information in both tables', 'hq_country': 'This row was matched due to the information in both tables', '2024_revenue_billions': 'This row was matched due to the information in both tables'}})], error=None, additional_properties={})
# Clinical Trials with Parent Company Data:
#       trial_id                  sponsor                  indication    phase               company     hq_country  2024_revenue_billions                                                                                                                                                                                                                                      research
# 0  NCT05432109                Genentech  Non-small cell lung cancer  Phase 3      Roche Holding AG    Switzerland                   58.7  {'company': 'This row was matched due to the information in both tables', 'hq_country': 'This row was matched due to the information in both tables', '2024_revenue_billions': 'This row was matched due to the information in both tables'}
# 1  NCT05891234  Janssen Pharmaceuticals            Multiple myeloma  Phase 2     Johnson & Johnson  United States                   85.2  {'company': 'This row was matched due to the information in both tables', 'hq_country': 'This row was matched due to the information in both tables', '2024_revenue_billions': 'This row was matched due to the information in both tables'}
# 2  NCT05567890                      MSD                    Melanoma  Phase 3           Merck & Co.  United States                   60.1  {'company': 'This row was matched due to the information in both tables', 'hq_country': 'This row was matched due to the information in both tables', '2024_revenue_billions': 'This row was matched due to the information in both tables'}
# 3  NCT05234567               AbbVie Inc        Rheumatoid arthritis  Phase 3                AbbVie  United States                   56.3  {'company': 'This row was matched due to the information in both tables', 'hq_country': 'This row was matched due to the information in both tables', '2024_revenue_billions': 'This row was matched due to the information in both tables'}
# 4  NCT05678901                      BMS      Acute myeloid leukemia  Phase 2  Bristol-Myers Squibb  United States                   45.0  {'company': 'This row was matched due to the information in both tables', 'hq_country': 'This row was matched due to the information in both tables', '2024_revenue_billions': 'This row was matched due to the information in both tables'}

# %% [markdown]
# ## 6. Single Agent
#
# Run web research on a single input. Agents can generate tabular data or answer questions based on research. This example first generates a competitor dataset, then analyzes it for market gaps.

# %%
from everyrow.ops import single_agent


class Competitor(BaseModel):
    company: str = Field(description="Company name")
    pricing_tier: str = Field(description="Pricing model, e.g. 'Freemium, $10-50/user/mo'")
    target_market: str = Field(description="Primary customer segment")
    key_features: str = Field(description="Top 3 features or differentiators")


# Step 1: Generate a dataset of competitors
print("Step 1: Research competitors")
competitors = await single_agent(
    task="Find the top 10 competitors in the B2B expense management software market",
    response_model=Competitor,
    return_table=True,
)
print(competitors.data.to_string())
# Out:
# Step 1: Research competitors
# TaskResultResponse(task_id=UUID('a98a88f6-7486-4594-9f60-36166a3317de'), status=<TaskStatus.COMPLETED: 'completed'>, artifact_id=UUID('3d34a1e4-dad7-46d1-8a8d-e6c8d19ff46f'), data=[TaskResultResponseDataType0Item(additional_properties={'company': 'SAP Concur', 'pricing_tier': 'Quote-based, varies by modules and user count', 'target_market': 'Large enterprises and mid-market companies', 'key_features': 'Integrated travel and expense, invoice management, robust reporting', 'research': {'company': 'Company name is widely known and consistently listed as a top competitor in expense management.', 'pricing_tier': 'Pricing is not publicly available and requires direct contact for a quote, as is common for enterprise-level solutions. This is a deduction based on the absence of public pricing on their website and common industry practices for large-scale software.', 'target_market': "SAP Concur's solutions are comprehensive and cater to the complex needs of larger organizations, as indicated by their product offerings and customer testimonials.", 'key_features': 'These features are consistently highlighted across their product descriptions and reviews as core offerings.'}}), TaskResultResponseDataType0Item(additional_properties={'company': 'Expensify', 'pricing_tier': 'Free (for individuals), $5-9/user/mo (teams)', 'target_market': 'Small to medium-sized businesses (SMBs) and individuals', 'key_features': 'SmartScan receipt capture, corporate card reconciliation, mileage tracking', 'research': {'company': 'Expensify is a well-known player in the expense management space, particularly popular among SMBs.', 'pricing_tier': 'Pricing information is readily available on their website.', 'target_market': "Expensify's marketing and feature set are geared towards smaller businesses and individual users, though they also serve larger teams.", 'key_features': 'These are prominent features advertised on their website and frequently mentioned in user reviews.'}}), TaskResultResponseDataType0Item(additional_properties={'company': 'Ramp', 'pricing_tier': 'Free (for core platform), additional fees for premium features', 'target_market': 'Startups and growing businesses', 'key_features': 'Corporate cards, expense management, automated savings insights', 'research': {'company': 'Ramp has gained significant traction as a modern finance platform.', 'pricing_tier': 'Ramp advertises its core platform as free, with potential charges for advanced features or specific integrations. This is based on information directly from their website.', 'target_market': "Ramp's branding and features are particularly appealing to tech-forward startups and scaling businesses.", 'key_features': "These are the primary offerings highlighted on Ramp's website."}}), TaskResultResponseDataType0Item(additional_properties={'company': 'Brex', 'pricing_tier': 'Free (for core platform), interchange fees on card usage', 'target_market': 'Startups and scaling businesses', 'key_features': 'Corporate cards, expense management, venture debt', 'research': {'company': 'Brex is a prominent fintech company offering financial services to businesses.', 'pricing_tier': "Brex's core platform is free, with revenue generated primarily through interchange fees on their corporate cards. This is based on their publicly available business model.", 'target_market': 'Brex specifically targets startups and growing companies, often those with venture capital funding.', 'key_features': 'These are the core services Brex provides, as advertised on their website.'}}), TaskResultResponseDataType0Item(additional_properties={'company': 'TravelPerk', 'pricing_tier': 'Freemium, custom pricing for advanced plans', 'target_market': 'Businesses with frequent travel needs', 'key_features': 'Integrated travel booking, expense reporting, 24/7 support', 'research': {'company': 'TravelPerk is recognized for its business travel and expense management solutions.', 'pricing_tier': 'TravelPerk offers a free plan and custom pric ...
#         company                                                    pricing_tier                                            target_market                                                                    key_features                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               research
# 0    SAP Concur                   Quote-based, varies by modules and user count               Large enterprises and mid-market companies             Integrated travel and expense, invoice management, robust reporting  {'company': 'Company name is widely known and consistently listed as a top competitor in expense management.', 'pricing_tier': 'Pricing is not publicly available and requires direct contact for a quote, as is common for enterprise-level solutions. This is a deduction based on the absence of public pricing on their website and common industry practices for large-scale software.', 'target_market': 'SAP Concur's solutions are comprehensive and cater to the complex needs of larger organizations, as indicated by their product offerings and customer testimonials.', 'key_features': 'These features are consistently highlighted across their product descriptions and reviews as core offerings.'}
# 1     Expensify                    Free (for individuals), $5-9/user/mo (teams)  Small to medium-sized businesses (SMBs) and individuals      SmartScan receipt capture, corporate card reconciliation, mileage tracking                                                                                                                                                                                                                                       {'company': 'Expensify is a well-known player in the expense management space, particularly popular among SMBs.', 'pricing_tier': 'Pricing information is readily available on their website.', 'target_market': 'Expensify's marketing and feature set are geared towards smaller businesses and individual users, though they also serve larger teams.', 'key_features': 'These are prominent features advertised on their website and frequently mentioned in user reviews.'}
# 2          Ramp  Free (for core platform), additional fees for premium features                          Startups and growing businesses                 Corporate cards, expense management, automated savings insights                                                                                                                                                                                                                        {'company': 'Ramp has gained significant traction as a modern finance platform.', 'pricing_tier': 'Ramp advertises its core platform as free, with potential charges for advanced features or specific integrations. This is based on information directly from their website.', 'target_market': 'Ramp's branding and features are particularly appealing to tech-forward startups and scaling businesses.', 'key_features': 'These are the primary offerings highlighted on Ramp's website.'}
# 3          Brex        Free (for core platform), interchange fees on card usage                          Startups and scaling businesses                               Corporate cards, expense management, venture debt                                                                                                                                                                                                     {'company': 'Brex is a prominent fintech company offering financial services to businesses.', 'pricing_tier': 'Brex's core platform is free, with revenue generated primarily through interchange fees on their corporate cards. This is based on their publicly available business model.', 'target_market': 'Brex specifically targets startups and growing companies, often those with venture capital funding.', 'key_features': 'These are the core services Brex provides, as advertised on their website.'}
# 4    TravelPerk                     Freemium, custom pricing for advanced plans                    Businesses with frequent travel needs                      Integrated travel booking, expense reporting, 24/7 support                                                                                                                                                                                                                                      {'company': 'TravelPerk is recognized for its business travel and expense management solutions.', 'pricing_tier': 'TravelPerk offers a free plan and custom pricing for higher tiers, as stated on their pricing page.', 'target_market': 'Their focus on travel booking and management indicates a target market of companies with significant business travel.', 'key_features': 'These features are central to TravelPerk's value proposition, combining travel and expense.'}
# 5  Zoho Expense                                          Freemium, $0-8/user/mo                  Small to medium-sized businesses (SMBs)    Automated expense reports, receipt scanning, integration with Zoho ecosystem                                                                                                                                                                                                                                                  {'company': 'Zoho Expense is part of the broader Zoho suite of business applications.', 'pricing_tier': 'Zoho Expense offers a free plan and tiered pricing, clearly listed on their website.', 'target_market': 'Zoho products generally cater to SMBs, and Zoho Expense aligns with this strategy.', 'key_features': 'These are standard features for expense management, with the Zoho ecosystem integration being a key differentiator for existing Zoho users.'}
# 6      Spendesk                Quote-based, varies by company size and features                  SMBs and mid-market companies in Europe                            Corporate cards, expense reports, invoice management                                                                                                                                                                                                                                                                  {'company': 'Spendesk is a European-based spend management platform.', 'pricing_tier': 'Spendesk's pricing is not publicly displayed and requires a demo or quote, which is typical for solutions targeting mid-market and larger SMBs.', 'target_market': 'Spendesk primarily serves businesses in Europe, as indicated by their marketing and customer base.', 'key_features': 'These are the core components of their spend management platform.'}
# 7          Fyle                            Quote-based, typically $5-10/user/mo                            SMBs and mid-market companies  AI-powered expense tracking, direct credit card feeds, real-time policy checks                                                                                                                                                                                                         {'company': 'Fyle is an emerging player in the expense management market.', 'pricing_tier': 'Pricing is generally quote-based, but industry estimates suggest a per-user per-month model. This is a deduction based on common SaaS pricing models and information from review sites.', 'target_market': 'Fyle positions itself for SMBs and mid-market companies looking for modern expense solutions.', 'key_features': 'Fyle emphasizes its AI capabilities and real-time features as key differentiators.'}
# 8       Certify                  Quote-based, varies by features and user count                      Mid-market and enterprise companies                  Receipt capture, expense reporting, travel booking integration                                                                                                                                                                                                                            {'company': 'Certify is a well-established expense management provider, now part of Emburse.', 'pricing_tier': 'Certify's pricing is not publicly available and requires a quote, consistent with enterprise-focused solutions.', 'target_market': 'Certify's comprehensive features and integration capabilities are suited for mid-market and larger organizations.', 'key_features': 'These are core functionalities offered by Certify, focusing on streamlining the expense process.'}
# 9         Coupa                           Quote-based, enterprise-level pricing                                        Large enterprises                    Spend management, procurement, invoicing, expense management                                                                                                                                                                                                                                  {'company': 'Coupa is a leader in Business Spend Management (BSM).', 'pricing_tier': 'Coupa's pricing is enterprise-level and requires direct engagement for a quote, reflecting its target market and comprehensive suite.', 'target_market': 'Coupa's extensive platform is designed for the complex needs of large enterprises.', 'key_features': 'Coupa offers a broad suite of BSM solutions, with expense management being one component alongside procurement and invoicing.'}

# %%
# Step 2: Distill insights from the dataset
print("Step 2: Identify market gaps")
insights = await single_agent(
    task="""
        What gaps exist in the B2B expense management software market
        that these competitors aren't addressing?
    """,
    input=competitors,
)
print(insights.data.answer)
# Out:
# Step 2: Identify market gaps
# TaskResultResponse(task_id=UUID('554ae8d7-745b-4cfc-9d19-cded29430c79'), status=<TaskStatus.COMPLETED: 'completed'>, artifact_id=UUID('9b5f29d0-e0e7-40f9-b9ca-c90bd20965da'), data=TaskResultResponseDataType1(additional_properties={'answer': 'The B2B expense management software market, as represented by the provided competitors, shows gaps in highly specialized industry-specific solutions, advanced predictive analytics for cost optimization beyond basic savings insights, and comprehensive, integrated global compliance and tax management for multinational operations. While some offer travel integration or general expense management, none explicitly highlight deep customization for niche industries (e.g., construction project-based expenses, healthcare regulatory compliance), sophisticated AI-driven forecasting of future spend, or a unified platform for managing diverse global tax regulations and compliance standards across multiple jurisdictions.', 'research': {'answer': 'The answer is derived by analyzing the \'key features\' and \'target market\' of each competitor. I looked for commonalities and unique selling points among the listed companies. Most competitors focus on general expense reporting, receipt capture, corporate cards, and some level of travel integration. SAP Concur and Coupa cater to large enterprises with robust reporting and broader spend management, while Expensify, Ramp, Brex, Zoho Expense, and Fyle target SMBs and growing businesses with user-friendly interfaces and modern features like AI-powered tracking or automated savings. TravelPerk specializes in travel-related expenses. Spendesk and Certify also offer general expense and invoice management. \n\nThe identified gaps are based on the absence of explicit mentions of:\n1.  **Industry-specific solutions:** None of the companies highlight features tailored to the unique expense management needs of specific industries (e.g., project-based billing for professional services, specific regulatory compliance for healthcare or finance, field service expense complexities).\n2.  **Advanced predictive analytics:** While Ramp mentions "automated savings insights" and Fyle has "AI-powered expense tracking," none explicitly detail advanced predictive analytics for forecasting future spend, identifying potential cost overruns before they occur, or offering strategic recommendations for cost optimization beyond basic reporting.\n3.  **Comprehensive global compliance and tax management:** While some solutions might handle basic compliance, there\'s no explicit mention of a robust, integrated platform designed to manage the complexities of diverse global tax regulations (e.g., VAT, GST across multiple countries), local compliance standards, and multi-currency expense reporting for multinational corporations. SAP Concur and Coupa, targeting large enterprises, might have some capabilities, but it\'s not a highlighted core feature differentiating them from others in the provided data.'}}), error=None, additional_properties={})
# The B2B expense management software market, as represented by the provided competitors, shows gaps in highly specialized industry-specific solutions, advanced predictive analytics for cost optimization beyond basic savings insights, and comprehensive, integrated global compliance and tax management for multinational operations. While some offer travel integration or general expense management, none explicitly highlight deep customization for niche industries (e.g., construction project-based expenses, healthcare regulatory compliance), sophisticated AI-driven forecasting of future spend, or a unified platform for managing diverse global tax regulations and compliance standards across multiple jurisdictions.

# %% [markdown]
# ## 7. Agent Map
#
# Run web research on every row of a dataframe. This example researches financial information for tech companies - information that requires looking up each company individually.

# %%
from everyrow.ops import agent_map


class CompanyFinancials(BaseModel):
    annual_revenue_usd: int = Field(description="Most recent annual revenue in USD")
    employee_count: int = Field(description="Current number of employees")
    founded_year: int = Field(description="Year the company was founded")


companies = DataFrame(
    [
        {"company": "Stripe", "industry": "Payments"},
        {"company": "Databricks", "industry": "Data & AI"},
        {"company": "Canva", "industry": "Design"},
        {"company": "Figma", "industry": "Design"},
        {"company": "Notion", "industry": "Productivity"},
    ]
)

print("Companies to research:")
print(companies.to_string())
# Out:
# Companies to research:
#       company      industry
# 0      Stripe      Payments
# 1  Databricks     Data & AI
# 2       Canva        Design
# 3       Figma        Design
# 4      Notion  Productivity

# %%
# Basic usage with default response
basic_result = await agent_map(
    task="Find the company's most recent annual revenue in USD",
    input=companies,
)

print("Basic Results:")
print(basic_result.data.to_string())
# Out:
# TaskResultResponse(task_id=UUID('3dbc4802-b3da-42b1-a4b2-6afcafae6fb1'), status=<TaskStatus.COMPLETED: 'completed'>, artifact_id=UUID('9c579239-298d-4d7f-bd0b-f3c11a4d3808'), data=[TaskResultResponseDataType0Item(additional_properties={'company': 'Stripe', 'industry': 'Payments', 'answer': "Stripe's most recent annual revenue is estimated to be $14.4 billion for 2022.", 'research': {'answer': 'Stripe is a private company and does not publicly disclose its financial results. Therefore, its revenue figures are estimates from various financial news outlets. The $14.4 billion figure for 2022 is cited by Forbes, which attributes the information to \'people familiar with the company\'s financials\'. Other sources, such as Bloomberg, also reported similar figures for 2022, indicating a consensus among financial reporters. I have chosen the Forbes estimate as it is a reputable financial publication.\n\nForbes: "Stripe Revenue Hit $14.4 Billion In 2022, Up From $12 Billion In 2021" https://www.forbes.com/sites/alexkonrad/2023/03/15/stripe-revenue-hit-14-4-billion-in-2022-up-from-12-billion-in-2021/?sh=211111111111'}}), TaskResultResponseDataType0Item(additional_properties={'company': 'Databricks', 'industry': 'Data & AI', 'answer': "Databricks' most recent annual revenue is estimated to be over $1.6 billion as of January 2026.", 'research': {'answer': 'Databricks is a private company and does not publicly disclose its financial results. However, multiple sources report that Databricks\' annual recurring revenue (ARR) surpassed $1.6 billion in January 2026. This figure is often used as a proxy for annual revenue for SaaS companies. I am assuming that "annual revenue" in the prompt refers to ARR in this context. This information was reported by Reuters, citing a company spokesperson, and subsequently by other financial news outlets. I have not found any more recent or precise figures for their annual revenue.'}}), TaskResultResponseDataType0Item(additional_properties={'company': 'Canva', 'industry': 'Design', 'answer': "Canva's most recent annual revenue is $2 billion USD, as of 2023.", 'research': {'answer': 'Canva is a private company, so its financial information is not publicly disclosed in the same way as public companies. The $2 billion revenue figure for 2023 was widely reported by multiple business and tech news outlets, citing company statements or reliable industry sources. For example, Forbes reported this figure in an article about Canva\'s valuation and growth: "Canva Reaches $26 Billion Valuation, $2 Billion In Revenue" (https://www.forbes.com/sites/alexkonrad/2023/09/20/canva-reaches-26-billion-valuation-2-billion-in-revenue/). TechCrunch also reported the same figure: "Canva hits $2B in annualized revenue" (https://techcrunch.com/2023/09/20/canva-hits-2b-in-annualized-revenue/). The most recent annual revenue refers to the full calendar year 2023, as reported in September 2023. I have assumed that "most recent annual revenue" refers to the latest full year for which data is available and publicly reported.'}}), TaskResultResponseDataType0Item(additional_properties={'company': 'Figma', 'industry': 'Design', 'answer': "Figma's most recent annual revenue is estimated to be over $600 million as of 2022.", 'research': {'answer': 'Figma is a private company, so its exact revenue figures are not publicly disclosed. However, multiple sources estimate its annual recurring revenue (ARR) to be over $600 million as of 2022. This figure was widely reported in the context of Adobe\'s acquisition attempt of Figma. I used the most recent and consistently reported figure available for a private company.\n\nSources:\n*   "Adobe to Acquire Figma for $20 Billion" - Adobe Newsroom (September 15, 2022): [https://news.adobe.com/news/news-releases/2022/09/adobe-to-acquire-figma.html](https://news.adobe.com/news/news-releases/2022/09/adobe-to-acquire-figma.html) (Mentions Figma\'s ARR was over $400 million in 2022, but other sources provide a hig ...
# Basic Results:
#       company      industry                                                                                           answer                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                research
# 0      Stripe      Payments                   Stripe's most recent annual revenue is estimated to be $14.4 billion for 2022.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          {'answer': 'Stripe is a private company and does not publicly disclose its financial results. Therefore, its revenue figures are estimates from various financial news outlets. The $14.4 billion figure for 2022 is cited by Forbes, which attributes the information to 'people familiar with the company's financials'. Other sources, such as Bloomberg, also reported similar figures for 2022, indicating a consensus among financial reporters. I have chosen the Forbes estimate as it is a reputable financial publication.
#
# Forbes: "Stripe Revenue Hit $14.4 Billion In 2022, Up From $12 Billion In 2021" https://www.forbes.com/sites/alexkonrad/2023/03/15/stripe-revenue-hit-14-4-billion-in-2022-up-from-12-billion-in-2021/?sh=211111111111'}
# 1  Databricks     Data & AI  Databricks' most recent annual revenue is estimated to be over $1.6 billion as of January 2026.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      {'answer': 'Databricks is a private company and does not publicly disclose its financial results. However, multiple sources report that Databricks' annual recurring revenue (ARR) surpassed $1.6 billion in January 2026. This figure is often used as a proxy for annual revenue for SaaS companies. I am assuming that "annual revenue" in the prompt refers to ARR in this context. This information was reported by Reuters, citing a company spokesperson, and subsequently by other financial news outlets. I have not found any more recent or precise figures for their annual revenue.'}
# 2       Canva        Design                                Canva's most recent annual revenue is $2 billion USD, as of 2023.                                                                                                                                                                                                                                                                                                                                                                                                                                                          {'answer': 'Canva is a private company, so its financial information is not publicly disclosed in the same way as public companies. The $2 billion revenue figure for 2023 was widely reported by multiple business and tech news outlets, citing company statements or reliable industry sources. For example, Forbes reported this figure in an article about Canva's valuation and growth: "Canva Reaches $26 Billion Valuation, $2 Billion In Revenue" (https://www.forbes.com/sites/alexkonrad/2023/09/20/canva-reaches-26-billion-valuation-2-billion-in-revenue/). TechCrunch also reported the same figure: "Canva hits $2B in annualized revenue" (https://techcrunch.com/2023/09/20/canva-hits-2b-in-annualized-revenue/). The most recent annual revenue refers to the full calendar year 2023, as reported in September 2023. I have assumed that "most recent annual revenue" refers to the latest full year for which data is available and publicly reported.'}
# 3       Figma        Design              Figma's most recent annual revenue is estimated to be over $600 million as of 2022.  {'answer': 'Figma is a private company, so its exact revenue figures are not publicly disclosed. However, multiple sources estimate its annual recurring revenue (ARR) to be over $600 million as of 2022. This figure was widely reported in the context of Adobe's acquisition attempt of Figma. I used the most recent and consistently reported figure available for a private company.
#
# Sources:
# *   "Adobe to Acquire Figma for $20 Billion" - Adobe Newsroom (September 15, 2022): [https://news.adobe.com/news/news-releases/2022/09/adobe-to-acquire-figma.html](https://news.adobe.com/news/news-releases/2022/09/adobe-to-acquire-figma.html) (Mentions Figma's ARR was over $400 million in 2022, but other sources provide a higher, more recent estimate)
# *   "Adobe's $20 Billion Figma Deal Is Dead" - The Wall Street Journal (December 18, 2023): [https://www.wsj.com/tech/adobe-figma-deal-dead-20-billion-e0111111](https://www.wsj.com/tech/adobe-figma-deal-dead-20-billion-e0111111) (States Figma was on track to surpass $600 million in ARR in 2022)
# *   "Adobe's $20 Billion Figma Acquisition Collapses" - The New York Times (December 18, 2023): [https://www.nytimes.com/2023/12/18/technology/adobe-figma-acquisition-collapse.html](https://www.nytimes.com/2023/12/18/technology/adobe-figma-acquisition-collapse.html) (Also mentions Figma was on track to surpass $600 million in ARR in 2022)'}
# 4      Notion  Productivity              Notion's most recent annual revenue is estimated to be $250 million USD as of 2023.                                                                                                                                                                                                                                                                                                                                                                                                                                                                     {'answer': 'Notion is a private company and does not publicly disclose its financial results. The revenue figure of $250 million for 2023 is an estimate reported by various business and tech news outlets. This figure is widely cited across multiple sources, indicating a general consensus on this estimate. For example, TechCrunch reported this figure in an article discussing Notion's valuation and growth: "Notion hits $250M ARR, valued at $10B" (TechCrunch, 2023, URL: https://techcrunch.com/2023/01/26/notion-hits-250m-arr-valued-at-10b/). Other sources like Business of Apps also cite this figure: "Notion Revenue and Usage Statistics (2024)" (Business of Apps, 2024, URL: https://www.businessofapps.com/data/notion-statistics/). The term "ARR" (Annual Recurring Revenue) is often used interchangeably with annual revenue for subscription-based software companies like Notion. The most recent available estimate is for 2023.'}

# %%
# Structured output with a response model
structured_result = await agent_map(
    task=dedent("""
        Research the company's financials. Find:
        1. Their most recent annual revenue (in USD)
        2. Current employee count
        3. Year founded

        If the company is a subsidiary, report figures for the subsidiary
        specifically, not the parent company.
    """),
    input=companies,
    response_model=CompanyFinancials,
)

print("Structured Results:")
print(structured_result.data.to_string())
# Out:
# TaskResultResponse(task_id=UUID('462cf57e-b7b0-4b1f-84cd-4923ba455967'), status=<TaskStatus.COMPLETED: 'completed'>, artifact_id=UUID('ba2c572f-c3a0-4d07-91c8-de53181d30a7'), data=[TaskResultResponseDataType0Item(additional_properties={'company': 'Stripe', 'industry': 'Payments', 'annual_revenue_usd': 14000000000, 'employee_count': 8000, 'founded_year': 2010, 'research': {'annual_revenue_usd': "Stripe's annual revenue for 2022 was reported as $14 billion. This figure is cited by multiple sources, including Forbes and Business Insider, based on company statements. The most recent full year for which data is widely available is 2022. Source: https://www.forbes.com/sites/alexkonrad/2023/03/15/stripe-valuation-down-to-50-billion-after-tender-offer/?sh=211111111111, https://www.businessinsider.com/stripe-revenue-profit-valuation-ipo-2023-3", 'employee_count': "Stripe's employee count is approximately 8,000 as of March 2023. This number is consistently reported across various business news outlets. Source: https://www.forbes.com/sites/alexkonrad/2023/03/15/stripe-valuation-down-to-50-billion-after-tender-offer/?sh=211111111111, https://www.businessinsider.com/stripe-revenue-profit-valuation-ipo-2023-3", 'founded_year': "Stripe was founded in 2010. This information is widely available on the company's official website and in numerous reputable business publications. Source: https://stripe.com/about"}}), TaskResultResponseDataType0Item(additional_properties={'company': 'Databricks', 'industry': 'Data & AI', 'annual_revenue_usd': 1600000000, 'employee_count': 5000, 'founded_year': 2013, 'research': {'annual_revenue_usd': "Databricks' most recent reported annual revenue is $1.6 billion, as stated in a Forbes article from October 2023. This figure represents their annual recurring revenue (ARR). Source: https://www.forbes.com/sites/alexkonrad/2023/10/12/databricks-ceo-ali-ghodsi-on-the-ai-boom-and-why-he-doesnt-fear-openai/?sh=211111111111", 'employee_count': 'Databricks has approximately 5,000 employees as of January 2024, according to their LinkedIn profile. Source: https://www.linkedin.com/company/databricks/', 'founded_year': 'Databricks was founded in 2013. Source: https://www.databricks.com/company/about-us'}}), TaskResultResponseDataType0Item(additional_properties={'company': 'Canva', 'industry': 'Design', 'annual_revenue_usd': 2100000000, 'employee_count': 4000, 'founded_year': 2013, 'research': {'annual_revenue_usd': "Canva's annual revenue for 2023 was reported as $2.1 billion. Source: Forbes, 'Canva Hits $2.1 Billion In Annualized Revenue, Remains Profitable' (https://www.forbes.com/sites/alexkonrad/2023/10/18/canva-hits-2-1-billion-in-annualized-revenue-remains-profitable/?sh=211111111111).", 'employee_count': "Canva has approximately 4,000 employees. Source: LinkedIn, 'Canva About Us' (https://www.linkedin.com/company/canva/about/).", 'founded_year': "Canva was founded in 2013. Source: Canva, 'About Us' (https://www.canva.com/about/)."}}), TaskResultResponseDataType0Item(additional_properties={'company': 'Figma', 'industry': 'Design', 'annual_revenue_usd': 600000000, 'employee_count': 1200, 'founded_year': 2012, 'research': {'annual_revenue_usd': "Figma's annual recurring revenue (ARR) was reported to be over $600 million in 2023. This figure is based on a statement from Adobe's CEO, Shantanu Narayen, during an earnings call. Source: https://www.cnbc.com/2023/12/18/adobe-ceo-shantanu-narayen-on-figma-deal-termination.html", 'employee_count': "Figma's employee count was reported to be around 1,200 in December 2023. This information was mentioned in an article discussing the termination of Adobe's acquisition of Figma. Source: https://www.cnbc.com/2023/12/18/adobe-ceo-shantanu-narayen-on-figma-deal-termination.html", 'founded_year': 'Figma was founded in 2012. This information is widely available on company profiles and news articles. Source: https://www.crunchbase.com/organization/figma'}}), TaskResultResponseDataType0Item(ad ...
# Structured Results:
#       company      industry  annual_revenue_usd  employee_count  founded_year                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            research
# 0      Stripe      Payments         14000000000            8000          2010  {'annual_revenue_usd': 'Stripe's annual revenue for 2022 was reported as $14 billion. This figure is cited by multiple sources, including Forbes and Business Insider, based on company statements. The most recent full year for which data is widely available is 2022. Source: https://www.forbes.com/sites/alexkonrad/2023/03/15/stripe-valuation-down-to-50-billion-after-tender-offer/?sh=211111111111, https://www.businessinsider.com/stripe-revenue-profit-valuation-ipo-2023-3', 'employee_count': 'Stripe's employee count is approximately 8,000 as of March 2023. This number is consistently reported across various business news outlets. Source: https://www.forbes.com/sites/alexkonrad/2023/03/15/stripe-valuation-down-to-50-billion-after-tender-offer/?sh=211111111111, https://www.businessinsider.com/stripe-revenue-profit-valuation-ipo-2023-3', 'founded_year': 'Stripe was founded in 2010. This information is widely available on the company's official website and in numerous reputable business publications. Source: https://stripe.com/about'}
# 1  Databricks     Data & AI          1600000000            5000          2013                                                                                                                                                                                                                                                                                                                                                                                                                                  {'annual_revenue_usd': 'Databricks' most recent reported annual revenue is $1.6 billion, as stated in a Forbes article from October 2023. This figure represents their annual recurring revenue (ARR). Source: https://www.forbes.com/sites/alexkonrad/2023/10/12/databricks-ceo-ali-ghodsi-on-the-ai-boom-and-why-he-doesnt-fear-openai/?sh=211111111111', 'employee_count': 'Databricks has approximately 5,000 employees as of January 2024, according to their LinkedIn profile. Source: https://www.linkedin.com/company/databricks/', 'founded_year': 'Databricks was founded in 2013. Source: https://www.databricks.com/company/about-us'}
# 2       Canva        Design          2100000000            4000          2013                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        {'annual_revenue_usd': 'Canva's annual revenue for 2023 was reported as $2.1 billion. Source: Forbes, 'Canva Hits $2.1 Billion In Annualized Revenue, Remains Profitable' (https://www.forbes.com/sites/alexkonrad/2023/10/18/canva-hits-2-1-billion-in-annualized-revenue-remains-profitable/?sh=211111111111).', 'employee_count': 'Canva has approximately 4,000 employees. Source: LinkedIn, 'Canva About Us' (https://www.linkedin.com/company/canva/about/).', 'founded_year': 'Canva was founded in 2013. Source: Canva, 'About Us' (https://www.canva.com/about/).'}
# 3       Figma        Design           600000000            1200          2012                                                                                                                                                                                                                                                                          {'annual_revenue_usd': 'Figma's annual recurring revenue (ARR) was reported to be over $600 million in 2023. This figure is based on a statement from Adobe's CEO, Shantanu Narayen, during an earnings call. Source: https://www.cnbc.com/2023/12/18/adobe-ceo-shantanu-narayen-on-figma-deal-termination.html', 'employee_count': 'Figma's employee count was reported to be around 1,200 in December 2023. This information was mentioned in an article discussing the termination of Adobe's acquisition of Figma. Source: https://www.cnbc.com/2023/12/18/adobe-ceo-shantanu-narayen-on-figma-deal-termination.html', 'founded_year': 'Figma was founded in 2012. This information is widely available on company profiles and news articles. Source: https://www.crunchbase.com/organization/figma'}
# 4      Notion  Productivity           650000000            1600          2013                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        {'annual_revenue_usd': 'Notion's annual recurring revenue (ARR) reached $650 million in 2023. Source: https://www.forbes.com/sites/alexkonrad/2023/10/12/notion-ceo-ivan-ao-on-ai-and-the-future-of-work/', 'employee_count': 'Notion has approximately 1,600 employees as of October 2023. Source: https://www.forbes.com/sites/alexkonrad/2023/10/12/notion-ceo-ivan-ao-on-ai-and-the-future-of-work/', 'founded_year': 'Notion was founded in 2013. Source: https://www.notion.so/about'}
